# %% [markdown]
# ## **Lectura 1: Simplex para problemas de asignación**

# %% [markdown]
# Supongamos que queremos asignar cuatro tareas a cuatro trabajadores (o procesos a máquinas, o inquilinos a casas, o personas en sitios de citas); en fin, relacionamientos uno a uno. Debemos suponer también que, para cada pareja, existe una medida de qué tan buena (o mala) es esa asignación, por ejemplo: cuánto le toma a cada trabajador o máquina hacer cada una de las tareas (y se quiere minimizar el tiempo), o qué tanto tienen en común dos usuarios del sitio de citas (y se quiere maximizar ese índice).

# %% [markdown]
# La formulación primal y dual del problema de asignación es la siguiente:
#
# - Sea $C$ una matriz de $n\times n$ de costos (o beneficios) de asignar la tarea $i$ al trabajador $j$.
#
# - Sea $x_{ij}$ una variable binaria que vale 1 si la tarea $i$ es asignada al trabajador $j$ y 0 en otro caso.
#
# - Sea $u_i$ y $v_j$ variables duales asociadas a las restricciones de que cada trabajador debe hacer una sola tarea y cada tarea debe ser hecha por un solo trabajador, respectivamente.

# %% [markdown]
# minimizar
#
# $$\sum_{i=1}^n\sum_{j=1}^n c_{ij}x_{ij}$$
#
# sujeto a
#
# $$\sum_{j=1}^n x_{ij} = 1 \forall i=1,\ldots,n$$
#
# $$\sum_{i=1}^n x_{ij} = 1 \forall j=1,\ldots,n$$
#
# $$x_{ij} \in \{0,1\} \forall i,j=1,\ldots,n$$

# %% [markdown]
# El problema dual es
#
# maximizar
#
# $$\sum_{i=1}^n u_i + \sum_{j=1}^n v_j$$
#
# sujeto a
#
# $$u_i + v_j \leq c_{ij}  \forall i,j=1,\ldots,n$$
#
# $$u_i \geq 0 \forall i=1,\ldots,n$$
#
# $$v_j \geq 0 \forall j=1,\ldots,n$$

# %% [markdown]
# Intentemos aplicar el algoritmo de transporte (dado que podemos ver al problema de asignación como un caso particular de dicho problema). Supongamos que una compañia quiere asignar 4 tareas a un conjunto de 4 maquinas y que el tiempo de alistamiento de las maquinas se muestra en la siguiente tabla:
#
# ![](../Images/ASSIGN_.png)

# %% [markdown]
# **Solución inicial**
#
# ![](../Images/ASSIGN_1.png)

# %% [markdown]
# Calculando los costos reducidos de las variables no básicas:
#
# - $\bar{c}_{11} = 11$
# - $\bar{c}_{21} = 1$
# - $\bar{c}_{22} = 9$
# - $\bar{c}_{23} = 0$
# - $\bar{c}_{31} = 8$
# - $\bar{c}_{32} = 7$
# - $\bar{c}_{34} = -1$
# - $\bar{c}_{43} = 4$
#
#
# Dado que tenemos un costo reducido negativo, la solución no es óptima.

# %% [markdown]
# **Iteración del simplex de transporte**
#
# ![](../Images/ASSIGN_2.png)
#
# ![](../Images/ASSIGN_3.png)

# %% [markdown]
# Vemos que: La solución óptima es degenerada
#
# - Aunque necesitamos $2m-1$ variables básicas, para que la solución sea factible se requiere apenas $m$ variables diferentes de cero.

# %% [markdown]
# Veamos un ejemplo concreto con máquinas y tareas. Supongamos que tenemos cuatro máquinas, y cuatro tareas. La siguiente tabla muestra el tiempo que le toma a cada máquina hacer cada tarea:

# %%
import pandas as pd

M = ["Maq. "+str(i) for i in range(1,5)]
T = ["Tarea "+str(i) for i in range(1,5)]

# Generar dataframe con costos de asignar cada tarea a cada máquina
asignacion = pd.DataFrame( {T[0]:[14,2,7,2],
                            T[1]:[5,12,8,4],
                            T[2]:[8,6,3,6],
                            T[3]:[7,5,9,10]}, index=M)
asignacion_copia = asignacion.copy()
asignacion
# Out:
#         Tarea 1  Tarea 2  Tarea 3  Tarea 4
# Maq. 1       14        5        8        7
# Maq. 2        2       12        6        5
# Maq. 3        7        8        3        9
# Maq. 4        2        4        6       10

# %% [markdown]
# ## 2. Cómo funciona el algoritmo de Kuhn
#
# Si uno hace una búsqueda en Internet, seguramente le dirán que el algoritmo de Kuhn hace lo siguiente:
#
# 1. **Inicialización**:
#     * Encuentre el mínimo valor de cada fila y réstelo de dicha fila.
#     * Luego, encuentre el mínimo valor de cada (nueva) columna y réstelo de ella.
# 2. **Verificación de "convergencia"**:
#     * Encuentre el menor número de líneas (horizontales y/o verticales) que permiten tachar todos los ceros que hayan aparecido en la nueva tabla.
#     * Si el número de líneas requerido es menor al número de asignaciones a lograr, entonces vaya al paso 3.
#     * Si, en cambio, hay tantas líneas como asignaciones a lograr, es posible encontrar una asignación factible, ¡y óptima!, entre las celdas que contengan ceros.
# 3. **Actualización**:
#     * Encuentre el menor valor entre las celdas no tachadas por líneas.
#     * Si a ese valor lo llamamos *k*, reste *k* de todas las celdas no cubiertas por líneas,
#     * Luego, sume *k* a aquellas celdas donde se crucen líneas.
#     * Vuelva al paso 2.

# %% [markdown]
# Veamos esto en nuestro ejemplo: El problema consiste en elegir un emparejamiento uno a uno de máquina y tarea que represente el menor costo posible; por ejemplo, en terminos de tiempo, si los valores de la tabla corresponden a tiempos que toman las tareas según la máquina.

# %%
# Encontrar mínimo de cada fila
asignacion["min_cada_fila"] = asignacion.min(axis=1)
asignacion
# Out:
#         Tarea 1  Tarea 2  Tarea 3  Tarea 4  min_cada_fila
# Maq. 1       14        5        8        7              5
# Maq. 2        2       12        6        5              2
# Maq. 3        7        8        3        9              3
# Maq. 4        2        4        6       10              2

# %%
# Restar a cada fila su mínimo (por practicidad hago la operación por columnas, pero la operación es en filas)
for i in range(4):
    asignacion.iloc[:,i] = asignacion.iloc[:,i].subtract(asignacion["min_cada_fila"])
asignacion
# Out:
#         Tarea 1  Tarea 2  Tarea 3  Tarea 4  min_cada_fila
# Maq. 1        9        0        3        2              5
# Maq. 2        0       10        4        3              2
# Maq. 3        4        5        0        6              3
# Maq. 4        0        2        4        8              2

# %%
import numpy as np

# encontrar mínimo de cada (nueva) columna
min_cols = asignacion.min()

# registrarlo
nueva_fila = pd.DataFrame( dict(zip(T+["min_cada_fila"], min_cols)), index=["min_cada_col"] )
nueva_fila.iloc[0,4] = np.nan

asignacion = asignacion.append(nueva_fila)
asignacion
# Out:
#               Tarea 1  Tarea 2  Tarea 3  Tarea 4  min_cada_fila
# Maq. 1              9        0        3        2            5.0
# Maq. 2              0       10        4        3            2.0
# Maq. 3              4        5        0        6            3.0
# Maq. 4              0        2        4        8            2.0
# min_cada_col        0        0        0        2            NaN

# %%
# restar a cada columna su mínimo
for i in range(4):
    asignacion.iloc[0:3,i] = asignacion.iloc[0:3,i] - asignacion.iloc[4,i]

# eliminar columnas agregadas antes
asignacion.drop("min_cada_fila", inplace=True, axis=1)
asignacion.drop("min_cada_col", inplace=True)

asignacion
# Out:
#         Tarea 1  Tarea 2  Tarea 3  Tarea 4
# Maq. 1        9        0        3        0
# Maq. 2        0       10        4        1
# Maq. 3        4        5        0        4
# Maq. 4        0        2        4        8

# %%
import resaltar

# Tachar ceros con MÍNIMA cantidad de líneas horizontales y verticales
asignacion.style.apply(resaltar.tabla, filas=[0,2], cols=[0], col_names=asignacion.columns)
# Out:
# <style  type="text/css" >
#     #T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col0 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col1 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col2 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col3 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row1_col0 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col0 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col1 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col2 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col3 {
#             background-color:  yellow;
#         }    #T_89b986e2_f770_11ea_883b_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89b986e2_f770_11ea_883b_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Tarea 1</th>
#         <th class="col_heading level0 col1" >Tarea 2</th>
#         <th class="col_heading level0 col2" >Tarea 3</th>
#         <th class="col_heading level0 col3" >Tarea 4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89b986e2_f770_11ea_883b_7c5cf8399c33" class="row_heading level0 row0" >Maq. 1</th>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col0" class="data row0 col0" >9</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col1" class="data row0 col1" >0</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col2" class="data row0 col2" >3</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row0_col3" class="data row0 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89b986e2_f770_11ea_883b_7c5cf8399c33" class="row_heading level0 row1" >Maq. 2</th>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row1_col0" class="data row1 col0" >0</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row1_col1" class="data row1 col1" >10</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row1_col2" class="data row1 col2" >4</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row1_col3" class="data row1 col3" >1</td>
#     </tr>    <tr>
#         <th id="T_89b986e2_f770_11ea_883b_7c5cf8399c33" class="row_heading level0 row2" >Maq. 3</th>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col0" class="data row2 col0" >4</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col1" class="data row2 col1" >5</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col2" class="data row2 col2" >0</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row2_col3" class="data row2 col3" >4</td>
#     </tr>    <tr>
#         <th id="T_89b986e2_f770_11ea_883b_7c5cf8399c33" class="row_heading level0 row3" >Maq. 4</th>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row3_col0" class="data row3 col0" >0</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row3_col1" class="data row3 col1" >2</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row3_col2" class="data row3 col2" >4</td>
#         <td id="T_89b986e2_f770_11ea_883b_7c5cf8399c33row3_col3" class="data row3 col3" >8</td>
#     </tr></tbody>
# </table>

# %%
# Dado que hay 3 líneas tachadas, y se deben hacer 4 asignaciones, NO hay convergencia aun...

# Encontrar mínimo de celdas no cubiertas y llamarlo k
k = min( asignacion.iloc[[1,3],[1,2,3]].min() )
print("Mínimo no cubierto es k="+str(k))

# Restar k de celdas no cubiertas (encontradas por inspección visual)
asignacion.iloc[[1,3],[1,2,3]] = asignacion.iloc[[1,3],[1,2,3]].apply(lambda x: x-k)

# Sumar k a celdas cubiertas dos veces (encontradas por inspección visual)
asignacion.iloc[0,0] = asignacion.iloc[0,0] + k
asignacion.iloc[2,0] = asignacion.iloc[2,0] + k

asignacion.style.apply(resaltar.celdas, cells=[(0,0),(2,0),(1,3)], col_names=asignacion.columns)
# Out:
# Mínimo no cubierto es k=1
# <style  type="text/css" >
#     #T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row0_col0 {
#             background-color:  yellow;
#         }    #T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row2_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Tarea 1</th>
#         <th class="col_heading level0 col1" >Tarea 2</th>
#         <th class="col_heading level0 col2" >Tarea 3</th>
#         <th class="col_heading level0 col3" >Tarea 4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33" class="row_heading level0 row0" >Maq. 1</th>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row0_col0" class="data row0 col0" >10</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row0_col1" class="data row0 col1" >0</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row0_col2" class="data row0 col2" >3</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row0_col3" class="data row0 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33" class="row_heading level0 row1" >Maq. 2</th>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row1_col0" class="data row1 col0" >0</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row1_col1" class="data row1 col1" >9</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row1_col2" class="data row1 col2" >3</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row1_col3" class="data row1 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33" class="row_heading level0 row2" >Maq. 3</th>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row2_col0" class="data row2 col0" >5</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row2_col1" class="data row2 col1" >5</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row2_col2" class="data row2 col2" >0</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row2_col3" class="data row2 col3" >4</td>
#     </tr>    <tr>
#         <th id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33" class="row_heading level0 row3" >Maq. 4</th>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row3_col0" class="data row3 col0" >0</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row3_col1" class="data row3 col1" >1</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row3_col2" class="data row3 col2" >3</td>
#         <td id="T_89bf2c46_f770_11ea_bcf1_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Cambiaron varios datos en la tabla:
# * El 10, 4, 1 de la Maq. 2 pasó a ser 9, 3, 0
# * El 2, 4, 8 de la Maq. 4 pasó a ser 1, 3, 7
# * El 9 y 4 de los cruces pasaron a 10 y 5
#
# De destacar: hay un nuevo cero.

# %%
# Tachar ceros con MÍNIMA cantidad de líneas horizontales y verticales
asignacion.style.apply(resaltar.tabla, filas=[0,2], cols=[0,3], col_names=asignacion.columns)
# Out:
# <style  type="text/css" >
#     #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col0 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col1 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col2 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col3 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col0 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col0 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col1 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col2 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col3 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }    #T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Tarea 1</th>
#         <th class="col_heading level0 col1" >Tarea 2</th>
#         <th class="col_heading level0 col2" >Tarea 3</th>
#         <th class="col_heading level0 col3" >Tarea 4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33" class="row_heading level0 row0" >Maq. 1</th>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col0" class="data row0 col0" >10</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col1" class="data row0 col1" >0</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col2" class="data row0 col2" >3</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row0_col3" class="data row0 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33" class="row_heading level0 row1" >Maq. 2</th>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col0" class="data row1 col0" >0</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col1" class="data row1 col1" >9</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col2" class="data row1 col2" >3</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row1_col3" class="data row1 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33" class="row_heading level0 row2" >Maq. 3</th>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col0" class="data row2 col0" >5</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col1" class="data row2 col1" >5</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col2" class="data row2 col2" >0</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row2_col3" class="data row2 col3" >4</td>
#     </tr>    <tr>
#         <th id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33" class="row_heading level0 row3" >Maq. 4</th>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col0" class="data row3 col0" >0</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col1" class="data row3 col1" >1</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col2" class="data row3 col2" >3</td>
#         <td id="T_89c51fca_f770_11ea_8a21_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Hay 4 líneas y se requieren 4 asignaciones. Si hago asignaciones donde hay ceros, dicha asignación será óptima. Solo es necesario elegir celdas factibles (no se asigna una tarea a más de una máquina, o una máquina a más de una tarea).

# %%
asignacion.style.apply(resaltar.celdas, cells=[(0,1),(1,3),(2,2),(3,0)], col_names=asignacion.columns)
# Out:
# <style  type="text/css" >
#     #T_89c8c95a_f770_11ea_a631_7c5cf8399c33row0_col1 {
#             background-color:  yellow;
#         }    #T_89c8c95a_f770_11ea_a631_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_89c8c95a_f770_11ea_a631_7c5cf8399c33row2_col2 {
#             background-color:  yellow;
#         }    #T_89c8c95a_f770_11ea_a631_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Tarea 1</th>
#         <th class="col_heading level0 col1" >Tarea 2</th>
#         <th class="col_heading level0 col2" >Tarea 3</th>
#         <th class="col_heading level0 col3" >Tarea 4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33" class="row_heading level0 row0" >Maq. 1</th>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row0_col0" class="data row0 col0" >10</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row0_col1" class="data row0 col1" >0</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row0_col2" class="data row0 col2" >3</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row0_col3" class="data row0 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33" class="row_heading level0 row1" >Maq. 2</th>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row1_col0" class="data row1 col0" >0</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row1_col1" class="data row1 col1" >9</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row1_col2" class="data row1 col2" >3</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row1_col3" class="data row1 col3" >0</td>
#     </tr>    <tr>
#         <th id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33" class="row_heading level0 row2" >Maq. 3</th>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row2_col0" class="data row2 col0" >5</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row2_col1" class="data row2 col1" >5</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row2_col2" class="data row2 col2" >0</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row2_col3" class="data row2 col3" >4</td>
#     </tr>    <tr>
#         <th id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33" class="row_heading level0 row3" >Maq. 4</th>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row3_col0" class="data row3 col0" >0</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row3_col1" class="data row3 col1" >1</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row3_col2" class="data row3 col2" >3</td>
#         <td id="T_89c8c95a_f770_11ea_a631_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Se ignoran los demás ceros puesto que se incurriría en dobles asignaciones. Sin embargo, se puede garantizar que la asignación hecha es ¡óptima!
#
# ¿Es en serio? La asignación implica los siguientes costos, si nos devolvemos a la tabla original:

# %%
# Revisar los costos de esa asignación sobre los costos originales del problema
asignacion_copia.style.apply(resaltar.celdas, cells=[(0,1),(1,3),(2,2),(3,0)], col_names=asignacion.columns)
# Out:
# <style  type="text/css" >
#     #T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row0_col1 {
#             background-color:  yellow;
#         }    #T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row2_col2 {
#             background-color:  yellow;
#         }    #T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Tarea 1</th>
#         <th class="col_heading level0 col1" >Tarea 2</th>
#         <th class="col_heading level0 col2" >Tarea 3</th>
#         <th class="col_heading level0 col3" >Tarea 4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33" class="row_heading level0 row0" >Maq. 1</th>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row0_col0" class="data row0 col0" >14</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row0_col1" class="data row0 col1" >5</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row0_col2" class="data row0 col2" >8</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row0_col3" class="data row0 col3" >7</td>
#     </tr>    <tr>
#         <th id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33" class="row_heading level0 row1" >Maq. 2</th>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row1_col0" class="data row1 col0" >2</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row1_col1" class="data row1 col1" >12</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row1_col2" class="data row1 col2" >6</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#     </tr>    <tr>
#         <th id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33" class="row_heading level0 row2" >Maq. 3</th>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row2_col0" class="data row2 col0" >7</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row2_col1" class="data row2 col1" >8</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row2_col3" class="data row2 col3" >9</td>
#     </tr>    <tr>
#         <th id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33" class="row_heading level0 row3" >Maq. 4</th>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row3_col0" class="data row3 col0" >2</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row3_col1" class="data row3 col1" >4</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row3_col2" class="data row3 col2" >6</td>
#         <td id="T_89cd5d4a_f770_11ea_aeb1_7c5cf8399c33row3_col3" class="data row3 col3" >10</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Lo anterior conlleva a que el costo total de asignar esas tareas a esas máquinas sea de $15.
#
# Los reto a encontrar una asignación de menor costo. No la van a encontrar. Pero ¿por qué?

# %% [markdown]
# ## 3. Qué ocurre detrás del algoritmo para decir que es exacto
#
# El problema descrito se puede escribir matemáticamente como:
#
# $$\min \sum\limits_{i\in\mathcal{O}}\sum\limits_{j\in\mathcal{D}}c_{ij}x_{ij}$$
#
#
# $$\sum\limits_{j\in\mathcal{D}}x_{ij} = 1, \forall i \in \mathcal{O}$$
#
# $$\sum\limits_{i\in\mathcal{O}}x_{ij} = 1, \forall j \in \mathcal{D}$$
#
# $$x_{ij} \geq 0, \forall i\in \mathcal{O},j\in \mathcal{D}$$
#
# Cuyo problema dual (relajando la integralidad de las variables) es:
#
# $$\max \sum\limits_{i\in \mathcal{O}}u_i + \sum\limits_{j\in \mathcal{D}}v_j$$
#
# $$ u_i + v_j \leq c_{ij}, \forall i\in \mathcal{O},j\in \mathcal{D}$$
#
# $$ u_i \in \mathbb{R}, \forall i\in \mathcal{O}$$
#
# $$ v_j \in \mathbb{R}, \forall j\in \mathcal{D}$$

# %%
min_filas = list(asignacion_copia.min(axis=1))
min_cols = [0,0,0,2] # mínimos sobre columna, pero después de restar, ver paso XX

duales = pd.DataFrame( {"u(i)":min_filas, "v(j)":min_cols}, index=[1,2,3,4] )
duales
# Out:
#    u(i)  v(j)
# 1     5     0
# 2     2     0
# 3     3     0
# 4     2     2

# %%
def actualizar_costos_red(duales):
    # Conjunto de arcos
    arcos = [(i,j) for i in range(1,5) for j in range(1,5)]
    
    # Costos reducidos
    cred = ["c("+str(i)+","+str(j)+")  -  u("+str(i)+")  -  v("+str(j)+")" for i in range(1,5) for j in range(1,5)]

    c = [asignacion_copia.iloc[i-1,j-1] for i in range(1,5) for j in range(1,5)]
    U = [duales.iloc[i-1,0] for i in range(1,5) for j in range(1,5)]
    V = [duales.iloc[j-1,1] for i in range(1,5) for j in range(1,5)]
    v_cred = [c[i]-U[i]-V[i] for i in range(len(c))]

    asignable = [i==0 for i in v_cred]    

    DF = pd.DataFrame({"(i,j)":arcos, 
                       "Valor costo c(i,j)":c, 
                       "Holgura Dual / C.Redu.Primal":cred,
                       "Valor u(i)":U,
                       "Valor v(j)":V,
                       "Result. 'costo red'":v_cred,
                       "Asignable?":asignable})
    DF.set_index("(i,j)", inplace=True)
    return DF

DF = actualizar_costos_red(duales)
colorear = [i for i in range(len(DF["Asignable?"])) if list(DF["Asignable?"])[i]]

DF.style.apply(resaltar.tabla, filas=colorear, cols=[], col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col0 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col1 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col2 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col4 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col5 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col1 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col2 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col3 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col4 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col5 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col0 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col1 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col2 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col3 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col4 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col5 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col0 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col1 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col2 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col3 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col4 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row10_col5 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col0 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col1 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col2 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col3 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col4 {
#             background-color:  yellow;
#         }    #T_89ddb136_f770_11ea_82af_7c5cf8399c33row12_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col2" class="data row0 col2" >9</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row0_col5" class="data row0 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col0" class="data row4 col0" >True</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col2" class="data row4 col2" >0</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col3" class="data row4 col3" >2</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col4" class="data row4 col4" >2</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row4_col5" class="data row4 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ddb136_f770_11ea_82af_7c5cf8399c33" class="row_heading level0 row5" >(2, 2)</th>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row5_col0" class="data row5 col0" >False</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row5_col1" class="data row5 col1" >c(2,2)  -  u(2)  -  v(2)</td>
#         <td id="T_89ddb136_f770_11ea_82af_7c5cf8399c33row5_co

# %% [markdown]
# Con las alternativas actuales de asignación no es posible generar una solución que no asigne más de una tarea a una máquina, o más de una máquina a una tarea.
#
# ¡Debemos generar un nuevo cero en la columna Result. 'costo red.'! Es decir, llevar una nueva holgura del dual a 0 para poder que una nueva variable del primal pueda tomar valor.
#
# ¿Cómo hacerlo? Podemos cambiar los valores de alguna(s) variables $u_i$ y/o $v_j$ a nuestro antojo, **siempre y cuando garanticemos que:**
#
# * No perdemos ninguno de los ceros que ya tenemos (porque perderíamos posibles asignaciones)
# * No se genera ningún valor negativo en "Result 'costo red.'" (porque eso implicaría que hay una holgura negativa en el dual, y que por lo tanto el dual es infactible)
#
# Por ejemplo, podemos llevar a cero el 1 de la fila (2,4) aumentando el valor de $u_2$ de 2 a 3.

# %%
duales.iloc[1,0] = 3

DF = actualizar_costos_red(duales)
colorear = [(i,j) for i in range(4,8) for j in [2,4]]

DF.style.apply(resaltar.celdas, cells=colorear, col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col2 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col4 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col2 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col4 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col2 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col4 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col2 {
#             background-color:  yellow;
#         }    #T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col4 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col2" class="data row0 col2" >9</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row0_col5" class="data row0 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col0" class="data row4 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col2" class="data row4 col2" >-1</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col3" class="data row4 col3" >2</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col4" class="data row4 col4" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row4_col5" class="data row4 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row5" >(2, 2)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col0" class="data row5 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col1" class="data row5 col1" >c(2,2)  -  u(2)  -  v(2)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col2" class="data row5 col2" >9</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col3" class="data row5 col3" >12</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col4" class="data row5 col4" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row5_col5" class="data row5 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row6" >(2, 3)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col0" class="data row6 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col1" class="data row6 col1" >c(2,3)  -  u(2)  -  v(3)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col2" class="data row6 col2" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col3" class="data row6 col3" >6</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col4" class="data row6 col4" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row6_col5" class="data row6 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row7" >(2, 4)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col0" class="data row7 col0" >True</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col1" class="data row7 col1" >c(2,4)  -  u(2)  -  v(4)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col2" class="data row7 col2" >0</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col3" class="data row7 col3" >5</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col4" class="data row7 col4" >3</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row7_col5" class="data row7 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33" class="row_heading level0 row8" >(3, 1)</th>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row8_col0" class="data row8 col0" >False</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row8_col1" class="data row8 col1" >c(3,1)  -  u(3)  -  v(1)</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf8399c33row8_col2" class="data row8 col2" >4</td>
#         <td id="T_89e6b20a_f770_11ea_b111_7c5cf839

# %% [markdown]
# Al cambiar $u_2$ de 2 a 3 (actualización señalada en verde), los valores de costos reducidos cambian para las celdas que dependen de $u_2$ (mostradas también en amarillo). En resumen:
#
# * Obtuvimos el cero que queríamos en la fila (2,4)
# * ¡En la fila (2,1) apareció un valor **negativo**!
#     * Perdimos un cero, pero más importante que eso...
#     * De dejarlo así, **el problema dual se haría infactible**
#
# ¿Cómo arreglarlo? Podríamos hacer que $v_1$, que se resta en la fila problemática (2,1), pase a valer -1 en vez de 0. Con eso:
# * Recuperamos factibilidad dual (porque volveríamos a holguras no negativas)
# * Recuperaríamos el cero, que por holgura complementaria permitiría asignar valor a la variable primal asociada

# %%
duales.iloc[0,1] = -1

DF = actualizar_costos_red(duales)
colorear = [(i,j) for i in [0,4,8,12] for j in [2,5]]

DF.style.apply(resaltar.celdas, cells=colorear, col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col2 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col5 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col2 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col5 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row8_col2 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row8_col5 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row12_col2 {
#             background-color:  yellow;
#         }    #T_89ef169a_f770_11ea_afdd_7c5cf8399c33row12_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col2" class="data row0 col2" >10</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row0_col5" class="data row0 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col0" class="data row4 col0" >True</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col2" class="data row4 col2" >0</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col3" class="data row4 col3" >2</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col4" class="data row4 col4" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row4_col5" class="data row4 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row5" >(2, 2)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col0" class="data row5 col0" >False</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col1" class="data row5 col1" >c(2,2)  -  u(2)  -  v(2)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col2" class="data row5 col2" >9</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col3" class="data row5 col3" >12</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col4" class="data row5 col4" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row5_col5" class="data row5 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row6" >(2, 3)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col0" class="data row6 col0" >False</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col1" class="data row6 col1" >c(2,3)  -  u(2)  -  v(3)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col2" class="data row6 col2" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col3" class="data row6 col3" >6</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col4" class="data row6 col4" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row6_col5" class="data row6 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row7" >(2, 4)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col0" class="data row7 col0" >True</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col1" class="data row7 col1" >c(2,4)  -  u(2)  -  v(4)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col2" class="data row7 col2" >0</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col3" class="data row7 col3" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col4" class="data row7 col4" >3</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row7_col5" class="data row7 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33" class="row_heading level0 row8" >(3, 1)</th>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row8_col0" class="data row8 col0" >False</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row8_col1" class="data row8 col1" >c(3,1)  -  u(3)  -  v(1)</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf8399c33row8_col2" class="data row8 col2" >5</td>
#         <td id="T_89ef169a_f770_11ea_afdd_7c5cf

# %% [markdown]
# Al cambiar $v_1$ de 0 a -1 (actualización señalada en verde), los valores de costos reducidos cambian para las celdas que dependen de $v_1$ (mostradas también en verde). En resumen:
#
# * Recuperamos la no-negatividad y el cero que queríamos en la fila (2,1)
# * Perdimos el cero que había en la fila (4,1); es decir, perdimos una posible asignación
#
# ¿Cómo arreglarlo? Podríamos hacer que $u_4$, que se resta en la fila problemática (2,1), pase a valer 3 en vez de 2. Con eso recuperaríamos el cero, que por holgura complementaria permitiría asignar valor a la variable primal asociada.

# %%
duales.iloc[3,0] = 3

DF = actualizar_costos_red(duales)
colorear = [(i,j) for i in range(12,16) for j in [2,4]]

DF.style.apply(resaltar.celdas, cells=colorear, col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row12_col2 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row12_col4 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row13_col2 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row13_col4 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row14_col2 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row14_col4 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row15_col2 {
#             background-color:  yellow;
#         }    #T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row15_col4 {
#             background-color:  yellow;
#         }</style>
# <table id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col2" class="data row0 col2" >10</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row0_col5" class="data row0 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col0" class="data row4 col0" >True</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col2" class="data row4 col2" >0</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col3" class="data row4 col3" >2</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col4" class="data row4 col4" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row4_col5" class="data row4 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row5" >(2, 2)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col0" class="data row5 col0" >False</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col1" class="data row5 col1" >c(2,2)  -  u(2)  -  v(2)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col2" class="data row5 col2" >9</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col3" class="data row5 col3" >12</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col4" class="data row5 col4" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row5_col5" class="data row5 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row6" >(2, 3)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col0" class="data row6 col0" >False</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col1" class="data row6 col1" >c(2,3)  -  u(2)  -  v(3)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col2" class="data row6 col2" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col3" class="data row6 col3" >6</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col4" class="data row6 col4" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row6_col5" class="data row6 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row7" >(2, 4)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col0" class="data row7 col0" >True</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col1" class="data row7 col1" >c(2,4)  -  u(2)  -  v(4)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col2" class="data row7 col2" >0</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col3" class="data row7 col3" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col4" class="data row7 col4" >3</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row7_col5" class="data row7 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33" class="row_heading level0 row8" >(3, 1)</th>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row8_col0" class="data row8 col0" >False</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row8_col1" class="data row8 col1" >c(3,1)  -  u(3)  -  v(1)</td>
#         <td id="T_89f7a238_f770_11ea_9d8b_7c5cf8399c33row8_col2" class="data row8 col2" >5</td>
#         <td id="T_89f7a238_f770_11ea_9d8b

# %% [markdown]
# ¡Hemos recuperado el cero **SIN** generar valores negativos ni perder otros ceros!
#
# Veamos qué asignaciones son posibles ahora, ya que deberíamos tener un cero más, o sea, un asignable más...

# %%
colorear = [i for i in range(len(DF["Asignable?"])) if list(DF["Asignable?"])[i]]

DF.style.apply(resaltar.tabla, filas=colorear, cols=[], col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col5 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col5 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col5 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row7_col5 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row10_col5 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col0 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col1 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col2 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col3 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col4 {
#             background-color:  yellow;
#         }    #T_8a0006c8_f770_11ea_a299_7c5cf8399c33row12_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col2" class="data row0 col2" >10</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row0_col5" class="data row0 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col0" class="data row4 col0" >True</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col2" class="data row4 col2" >0</td>
#         <td id="T_8a0006c8_f770_11ea_a299_7c5cf8399c33row4_col3" class="da

# %% [markdown]
# Sobre esta versión SÍ podemos hacer una asignación factible (que no se asigne más de una máquina a una tarea o viceversa).

# %%
colorear = [1,7,10,12]

DF.style.apply(resaltar.tabla, filas=colorear, cols=[], col_names=DF.columns)
# Out:
# <style  type="text/css" >
#     #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col0 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col1 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col2 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col3 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col4 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col5 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col0 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col1 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col2 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col3 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col4 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row7_col5 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col0 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col1 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col2 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col3 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col4 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row10_col5 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col0 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col1 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col2 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col3 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col4 {
#             background-color:  yellow;
#         }    #T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row12_col5 {
#             background-color:  yellow;
#         }</style>
# <table id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Asignable?</th>
#         <th class="col_heading level0 col1" >Holgura Dual / C.Redu.Primal</th>
#         <th class="col_heading level0 col2" >Result. 'costo red'</th>
#         <th class="col_heading level0 col3" >Valor costo c(i,j)</th>
#         <th class="col_heading level0 col4" >Valor u(i)</th>
#         <th class="col_heading level0 col5" >Valor v(j)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >(i,j)</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row0" >(1, 1)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col0" class="data row0 col0" >False</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col1" class="data row0 col1" >c(1,1)  -  u(1)  -  v(1)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col2" class="data row0 col2" >10</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col3" class="data row0 col3" >14</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col4" class="data row0 col4" >5</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row0_col5" class="data row0 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row1" >(1, 2)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col0" class="data row1 col0" >True</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col1" class="data row1 col1" >c(1,2)  -  u(1)  -  v(2)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col2" class="data row1 col2" >0</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col3" class="data row1 col3" >5</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col4" class="data row1 col4" >5</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row1_col5" class="data row1 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row2" >(1, 3)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col0" class="data row2 col0" >False</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col1" class="data row2 col1" >c(1,3)  -  u(1)  -  v(3)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col2" class="data row2 col2" >3</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col3" class="data row2 col3" >8</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col4" class="data row2 col4" >5</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row2_col5" class="data row2 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row3" >(1, 4)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col0" class="data row3 col0" >True</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col1" class="data row3 col1" >c(1,4)  -  u(1)  -  v(4)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col2" class="data row3 col2" >0</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col3" class="data row3 col3" >7</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col4" class="data row3 col4" >5</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row3_col5" class="data row3 col5" >2</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row4" >(2, 1)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col0" class="data row4 col0" >True</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col1" class="data row4 col1" >c(2,1)  -  u(2)  -  v(1)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col2" class="data row4 col2" >0</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col3" class="data row4 col3" >2</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col4" class="data row4 col4" >3</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row4_col5" class="data row4 col5" >-1</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row5" >(2, 2)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col0" class="data row5 col0" >False</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col1" class="data row5 col1" >c(2,2)  -  u(2)  -  v(2)</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col2" class="data row5 col2" >9</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col3" class="data row5 col3" >12</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col4" class="data row5 col4" >3</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row5_col5" class="data row5 col5" >0</td>
#     </tr>    <tr>
#         <th id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33" class="row_heading level0 row6" >(2, 3)</th>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row6_col0" class="data row6 col0" >False</td>
#         <td id="T_8a097ccc_f770_11ea_b1eb_7c5cf8399c33row6_col1"

# %% [markdown]
# ¡LA MISMA SOLUCIÓN QUE HABÍAMOS LOGRADO CON LAS REGLAS LOCAS!
#
# Los ceros que no se usan corresponden al típico degeneramiento que presentan los problemas de asignación. La base debe ser de tamaño igual a dos veces el número de nodos ($m$) menos uno, pero para tener una asignación factible, solo $m$ toman valor.

# %% [markdown]
# **Observaciones:**
#
# * Cuando se toma la tabla de costos y se restan los mínimos de fila y columna, se están calculando en cada celda los **costos reducidos del problema primal**, que son las mismas holguras del dual, a través de darle valores arbitrarios *pero factibles* a las variables duales (son factibles al evitar que las holguras, o valores de las celdas, se hagan negativas).
#
# * Esa solución es factible para el dual **pero NO para el primal** (o no necesariamente). En efecto, no era posible hacer asignaciones factibles (uno a uno) con las condiciones de holgura complementaria de la primera iteración (es decir, como solo pueden tomar valor las variables relacionadas con holguras duales en cero, no se lograba el uno a uno).
#
# * Conclusión de lo anterior: **el dual era factible pero el primal NO**. No se dejen engañar. Todos los costos reducidos para el problema primal de minimización eran positivos (ya que las holguras duales lo eran), PERO NO se podía decretar optimalidad, ya que **NO** había factibilidad primal; no se cumplían las condiciones KKT.
#
# Cómo opera el algoritmo:
# 1. Empieza con una solución dual factible ($u_i$ y $v_j$ triviales que no hagan negativos sus $c_{ij}$)
# 2. Revisa si hay factibilidad primal
#     * Si sí, hay optimalidad por KKT
#     * Si no, pasa a 3
# 3. Aumenta el valor de una dual buscando un nuevo cero en holguras (apretar restricciones), PERO:
#     * Debe reducir el valor de otra(s) dual(es) para revertir holguras que se hayan negativos
#     * Debe aumentar el valor de otra(s) dual(es) más para recuperar ceros perdidos
#     * Volver a 2
#
# En el fondo, se hace lo mismo que en Simplex, pero desde la perspectiva del problema dual. Es decir: (i) partir de una solución factible; (ii) verificar costos reducidos (¡que es verificar factibilidad dual!); (iii) moverme buscando factibilidad dual SIN PERDER la primal. Cuando Simplex, desde su factibilidad primal, encuentra factibilidad dual (i.e., costos reducidos que no prometen), entonces decreta optimalidad.
#
# Este tipo de algoritmos se conocen como Simplex-Dual, y desde su factibilidad dual tratan de mejorar su función objetivo; cuando encuentran factibilidad primal, decretan optimalidad.

# %% [markdown]
# ## Glosario de pre-requisitos
#
# Algunas cosas que vale la pena recordar sobre programación lineal para entender el proceso. Solamente se menciona la idea general de cada caso, pero se recomienda profundizar en ellos si no se dominan.
#
# * *Holgura complementaria*: Si una restricción se cumple con igualdad (i.e., su holgura es cero), entonces la variable asociada a dicha restricción en el problema dual debe tomar valor. Si, por el contrario, una restricción se cumple con desigualdad (i.e., su holgura toma valor), entonces la variable asociada a dicha restricción en el problema dual TIENE que ser cero.
#
# * Los costos reducidos del problema primal son equivalentes a las variables de holgura del problema dual.
#
# * *Condiciones de optimalidad de Karush-Kuhn-Tucker (KKT)*: para garantizar que un problema es óptimo, se debe cumplir:
#     * Factibilidad primal
#     * Factibilidad dual (o sea costos reducidos "favorables" en el primal)
#     * Holgura complementaria

# %% [markdown]
# **Ejercicio**
#
# Resuelva usando el algoritmo de Kuhn el siguiente problema de asignación:
#
# El entrenador de la selección colombiana de natación tiene que determinar quién participará en una carrera de 4x100 metros.
#
# ![](../Images/ASSIGN_4.png)
#
#
# ¿Cómo debe elegir el entrenador a los miembros del equipo?
