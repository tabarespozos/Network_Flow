# %% [markdown]
# **Profesores:** David Álvarez-Martínez y Alejandra Tabares
#
# **Horario:** Martes y Jueves. 15:30 – 16:50.
#
# **Lugar:** RGD 202
#
# ##

# %% [markdown]
# ## Descripción
#
# El curso presenta al estudiante los aspectos de modelaje y diseño
# algorítmico de un primer curso de optimización en redes. El curso tiene
# un enfoque de programación matemática, como continuación natural de un
# curso en optimización lineal (Principios de Optimización). Algunos temas
# siguen un enfoque combinatorio, sirviendo como un primer curso en el
# área de optimización combinatoria. El tema de optimización en redes
# tiene una amplia aplicabilidad, además de encontrar relaciones directas
# con la ciencia de redes y la matemática discreta. Algunos ejemplos de su
# uso son: redes de transporte, redes de comunicaciones, planeación de
# capital, programación de proyectos, mantenimiento y reemplazo de
# equipos, programación de producción, entre otros.
#
# ##

# %% [markdown]
# ## Contenido
#
# <table>
# <colgroup>
# <col style="width: 5%" />
# <col style="width: 18%" />
# <col style="width: 33%" />
# <col style="width: 21%" />
# <col style="width: 20%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="2"><strong>Semana</strong></th>
# <th><strong>Tema</strong></th>
# <th><strong>Lecturas</strong></th>
# <th><strong>Tareas / Exámenes</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td rowspan="2">1</td>
# <td rowspan="2">Ago 07 – Ago11</td>
# <td>Introducción</td>
# <td>Ahuja et al., pág. 1-22</td>
# <td rowspan="2"><strong>Lanzamiento Proyecto</strong></td>
# </tr>
# <tr class="even">
# <td>Conceptos básicos</td>
# <td>Notas de Clase</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">2</td>
# <td rowspan="2">Ago 14 - Ago 18</td>
# <td>Flujo en redes como PL</td>
# <td rowspan="2">Ahuja et al., pág. 23-52</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="even">
# <td>Herramientas computacionales</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">3</td>
# <td rowspan="2">Ago 21 - Ago 25</td>
# <td>Representación de redes</td>
# <td>Notas de Clase</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="even">
# <td>Rev. programación lineal</td>
# <td>Fang et al., pág.29-51</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">4</td>
# <td rowspan="2">Ago 28 – Sep 01</td>
# <td rowspan="2">Problema de transporte</td>
# <td>Notas de Clase</td>
# <td rowspan="2"><strong>Proyecto Entrega 1</strong></td>
# </tr>
# <tr class="even">
# <td>Bazaraa et al., pág 505-527</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">5</td>
# <td rowspan="2">Sep 04 - Sep 08</td>
# <td rowspan="2">Transporte con var. acotadas</td>
# <td>Notas de Clase</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="even">
# <td>Bazaraa et al., pág 505-527</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">6</td>
# <td rowspan="2">Sep 11 - Sep 15</td>
# <td rowspan="2">Problema de asignación y otros</td>
# <td>Notas de Clase</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="even">
# <td>Bazaraa et al., pág 527-554</td>
# </tr>
# <tr class="odd">
# <td rowspan="2">7</td>
# <td rowspan="2">Sep 18 - Sep 22</td>
# <td rowspan="2">Árbol generatriz mínimo (MST)<br />
# Flujo de costo mínimo</td>
# <td>Notas de Clase</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Bazaraa et al., pág 527-554</td>
# <td><strong>Proyecto Entrega 2</strong></td>
# </tr>
# <tr class="odd">
# <td rowspan="2">8</td>
# <td rowspan="2">Sep 25 - Sep 29</td>
# <td rowspan="2"><p>Redes multiflujos</p>
# <p>Flujo máximo</p></td>
# <td>Notas de Clase</td>
# <td rowspan="2"><strong>Parcial 1<br />
# </strong></td>
# </tr>
# <tr class="even">
# <td>Bazaraa et al., pág 445-473</td>
# </tr>
# <tr class="odd">
# <td>9</td>
# <td>Oct 02 – Oct 06</td>
# <td colspan="3"><strong>SEMANA DE TRABAJO INDIVIDUAL</strong></td>
# </tr>
# <tr class="even">
# <td rowspan="2">10</td>
# <td rowspan="2">Oct 09 - Oct 13</td>
# <td rowspan="2"><p>Ruta más corta</p>
# <p>Algoritmo Bellman Ford</p></td>
# <td>Notas de Clase</td>
# <td rowspan="2"><strong>Proyecto Entrega 3</strong></td>
# </tr>
# <tr class="odd">
# <td>Ahuja et al., pág. 510-542</td>
# </tr>
# <tr class="even">
# <td rowspan="2">11</td>
# <td rowspan="2">Oct 16 - Oct 20</td>
# <td rowspan="2">Ruta más corta con restricciones de recursos</td>
# <td>Medaglia et al.</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="odd">
# <td></td>
# </tr>
# <tr class="even">
# <td rowspan="2">12</td>
# <td rowspan="2">Oct 23 - Oct 27</td>
# <td rowspan="2"><p>Estructuras de Datos</p>
# <p>Notación Asintótica</p></td>
# <td>Garey y Johnson, pág.1-50</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="odd">
# <td>Ahuja et al., pág. 93-165</td>
# </tr>
# <tr class="even">
# <td>13</td>
# <td>Oct 30 – Nov 03</td>
# <td>Complejidad</td>
# <td>Ahuja et al., pág. 93-165</td>
# <td><strong>Proyecto Entrega 4</strong></td>
# </tr>
# <tr class="odd">
# <td rowspan="2">14</td>
# <td rowspan="2">Nov 06 - Nov 10</td>
# <td rowspan="2">Problema del Cartero Viajante</td>
# <td>Toth y Vigo, pág. 1-83</td>
# <td rowspan="2"></td>
# </tr>
# <tr class="even">
# <td></td>
# </tr>
# <tr class="odd">
# <td>15</td>
# <td>Nov 13 - Nov 17</td>
# <td>Ruteo de Vehículos</td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td rowspan="2">16</td>
# <td rowspan="2">Nov 20 – Nov 24</td>
# <td rowspan="2">Ruteo de Vehículos</td>
# <td rowspan="2"><p>Toth y Vigo, pág. 87-110 </p>
# <p>Prins, 2004</p></td>
# <td><strong>Proyecto Entrega 5</strong></td>
# </tr>
# <tr class="odd">
# <td></td>
# </tr>
# <tr class="even">
# <td>17</td>
# <td>Nov 27 – Dic 01</td>
# <td>Ruteo en Arcos</td>
# <td>Notas de Clase</td>
# <td><strong>Parcial 2</strong></td>
# </tr>
# <tr class="odd">
# <td>18</td>
# <td>Dic 04 – Dic 08</td>
# <td colspan="2"><strong>SEMANA EXÁMENES FINALES</strong></td>
# <td><strong>Entrega Final</strong></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Evaluación
#
# <table>
# <colgroup>
# <col style="width: 21%" />
# <col style="width: 66%" />
# <col style="width: 12%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>Actividad</strong></p>
# </blockquote></th>
# <th><strong>Temática</strong></th>
# <th><strong>Porcentaje</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Parcial 1</p>
# </blockquote></td>
# <td>Modelamiento</td>
# <td>20%</td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Parcial 2</p>
# </blockquote></td>
# <td>Implementación</td>
# <td><blockquote>
# <p>20%</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Proyecto Entrega 1</p>
# </blockquote></td>
# <td>Introducción</td>
# <td><blockquote>
# <p>5%</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Proyecto Entrega 2</p>
# </blockquote></td>
# <td>Estado del arte</td>
# <td><blockquote>
# <p>5%</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Proyecto Entrega 3</p>
# </blockquote></td>
# <td>Formulación</td>
# <td><blockquote>
# <p>15%</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Proyecto Entrega 4</p>
# </blockquote></td>
# <td>Instancias, diseño de experimentos y visualización de
# resultados</td>
# <td><blockquote>
# <p>5%</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Proyecto Entrega 5</p>
# </blockquote></td>
# <td>Implementación y estrategias de aceleración</td>
# <td><blockquote>
# <p>15%</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Proyecto Final</p>
# </blockquote></td>
# <td>Documento y presentación final</td>
# <td><blockquote>
# <p>15%</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Requisitos
#
# Optimización lineal y Programación (algún lenguaje formal como Python,
# Java, C, C++, entre otros).
#
# ## Metodología
#
# Clases magistrales.
#
# El curso tiene un sitio oficial en Bloque Neon
# (<http://bloqueneon.uniandes.edu.co>) donde se publicará toda la
# información pertinente al curso.
#
# Es responsabilidad del estudiante consultar regularmente el sitio del
# curso.
#
# ## Reglas
#
# -   La nota definitiva del curso se calcula aproximando a dos decimales
#     el promedio ponderado de los parciales y los proyectos.
#
# -   En Bloque Neon se publicarán todos los cambios al programa, siendo
#     responsabilidad del estudiante visitar Bloque Neon regularmente.
#
# -   El tamaño máximo de los grupos para los proyectos es de **2
#     personas**.
#
# ## Horario de Atención
#
# Alejandra Tabares (<a.tabares@uniandes.edu.co> )
#
# -   ML-622, Lunes 10:30 a.m.-11:30 a.m. (agendamiento previo)
#
# David Álvarez (<d.alvarezm@uniandes.edu.co>)
#
# -   ML-757, Lunes 12:00 m.-13:00 p.m. o WhatsApp +573117346940
#     (agendamiento previo)

# %% [markdown]
# ## Bibliografía
#
# -   Ahuja, R. K., Magnanti, T. L. y Orlin, J. B. Network Flows.
#     > Prentice-Hall, 1993.
#
# -   Bazaraa, M. S., Jarvis, J. J. y Sherali, H. D. Linear Programming
#     > and Network Flows. Wiley, 1990.
#
# -   Bolivar, M. A., Lozano, L., Medaglia, A. L. (2014). Acceleration
#     > Strategies for the Weight Constrained Shortest Path Problem with
#     > Replenishment. *Optimization Letters.*8 (8): 2155-2172.
#
# -   Bertsimas, D., Tsitsiklis, N. J. Introduction to Linear
#     > Optimization. Athena Scientific, 1997.
#
# -   Duque, D., Lozano, L., Medaglia, A. L. (2015). An Exact Method for
#     > the Biobjective Shortest Path Problem for Large-Scale Road
#     > Networks. *European Journal of Operational Research*. 2 (3):
#     > 788-797.
#
# -   Duque, D., Lozano, L., Medaglia, A. L. (2014). Solving the
#     > orienteering problem with time windows via the Pulse Framework.
#     > *Computers & Operations Research*. 54: 168-176.
#
# -   Fang, S. C. y Puthenpura, S. Linear Optimization and Extensions:
#     > Theory and Algorithms. Prentice-Hall, 1993.
#
# -   Lozano, L., Duque, D., Medaglia, A. L. (2014). An exact algorithm
#     > for the elementary shortest path problem with resource
#     > constraints. *Transportation Science*. In press.
#
# -   Lozano, L., Medaglia, A. L. (2013). On an exact method for the
#     > constrained shortest path problem. *Computers & Operations
#     > Research*. 40 (1): 378-384.
#
# -   Medaglia, A. Flujo en Redes: Notas de Clase. Departamento de
#     > Ingeniería Industrial, Universidad de los Andes.
#
# -   Toth, P. y Vigo, D., Vehicle Routing: Problems, Methods, and
#     > Applications, 2014.
#
# -   Garey M. R. y Johnson, D. S., Computers and Intractability: A Guide
#     > to the Theory of NP-Completeness, 1979.
